# %% [markdown]
# 1. Scenario: A company wants to analyze the sales performance of its products in different regions. They have collected the following data:
#
#    Region A: [10, 15, 12, 8, 14]
#
#    Region B: [18, 20, 16, 22, 25]
#
#    Calculate the mean sales for each region.
#
# Ans.
#
# Region A Mean = 11.8
#
# Region B Mean = 20.2

# %% [markdown]
# 2. Scenario: A survey is conducted to measure customer satisfaction on a scale of 1 to 5. The data collected is as follows:
#
#    [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
#
#    Calculate the mode of the survey responses.
#
# Ans.
#
# Mode is [4,5]

# %% [markdown]
# 3. Scenario: A company wants to compare the salaries of two departments. The salary data for Department A and Department B are as follows:
#
#    Department A: [5000, 6000, 5500, 7000]
#
#    Department B: [4500, 5500, 5800, 6000, 5200]
#
#    Calculate the median salary for each department.
#
# Ans.
#
# Department A median : 5750
#
# Department B median : 5500

# %% [markdown]
# 4. Scenario: A data analyst wants to determine the variability in the daily stock prices of a company. The data collected is as follows:
#
#    [25.5, 24.8, 26.1, 25.3, 24.9]
#
#    Calculate the range of the stock prices.
#
# Ans.
#
# 1.3

# %% [markdown]
# 5. Scenario: A study is conducted to compare the performance of two different teaching methods. The test scores of the students in each group are as follows:
#
#    Group A: [85, 90, 92, 88, 91]
#
#    Group B: [82, 88, 90, 86, 87]
#
#    Perform a t-test to determine if there is a significant difference in the mean scores between the two groups.
#
# Ans.
#
# 1. H0(Null Hypothesis):- There is no difference in mean between both group
# 2. H1(Alternate Hypothesis):- There is difference in mean between both group
#
# ![T-test.png](attachment:T-test.png)
#
# Degree of freedom=n1+n2-2=5+5-2=8
# Let alpha=0.05
#
# According to t table, where alpha =0.5 and two tailed, where degree of freedom =8, then t value=2.306
#
#
# Result:
#
# T-test Value	1.42
#
# t Value (95% confidence level)	2.306
#
# Our Analysis	T-test Value < Critical Value
#
# Our Conclusion	Accept Null Hypothesis
#
# It means there is a no difference between the satisfaction ratings of both group.

# %% [markdown]
# 6. Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
#
#    Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#
#    Sales (in thousands): [25, 30, 28, 20, 26]
#
#    Calculate the correlation coefficient between advertising expenditure and sales.
#
#
#    Ans.

# %% [markdown]
# ![Covariance-Formula.jpg](attachment:Covariance-Formula.jpg)

# %% [markdown]
# ![cov_x_y.png](attachment:cov_x_y.png)

# %% [markdown]
# 7. Scenario: A survey is conducted to measure the heights of a group of people. The data collected is as follows:
#    [160, 170, 165, 155, 175, 180, 170]
#    Calculate the standard deviation of the heights.
#
# Ans
# ![standard_deviation-2.png](attachment:standard_deviation-2.png)

# %% [markdown]
# ![standard_deviation_out.png](attachment:standard_deviation_out.png)

# %% [markdown]
# 8. Scenario: A company wants to analyze the relationship between employee tenure and job satisfaction. The data collected is as follows:
#
#    Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
#
#    Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
#    Perform a linear regression analysis to predict job satisfaction based on employee tenure.

# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# Employee Tenure (in years)
tenure = np.array([2, 3, 5, 4, 6, 2, 4])

# Job Satisfaction (on a scale of 1 to 10)
satisfaction = np.array([7, 8, 6, 9, 5, 7, 6])

# Perform linear regression analysis
slope, intercept, r_value, p_value, std_err = linregress(tenure, satisfaction)

# Predict job satisfaction based on tenure
predicted_satisfaction = slope * tenure + intercept

# Plot the data points and the regression line
plt.scatter(tenure, satisfaction, label='Data')
plt.plot(tenure, predicted_satisfaction, color='red', label='Linear Regression')
plt.xlabel('Employee Tenure (years)')
plt.ylabel('Job Satisfaction')
plt.title('Linear Regression Analysis')
plt.legend()
plt.grid(True)
plt.show()

# Print the regression results
print("Slope (Regression Coefficient):", slope)
print("Intercept:", intercept)
print("R-squared value:", r_value**2)
# Out:
# Slope (Regression Coefficient): -0.4680851063829787
# Intercept: 8.595744680851062
# R-squared value: 0.27099664053751393

# %% [markdown]
# 9. Scenario: A study is conducted to compare the effectiveness of two different medications. The recovery times of the patients in each group are as follows:
#
#    Medication A: [10, 12, 14, 11, 13]
#
#    Medication B: [15, 17, 16, 14, 18]
#
#    Perform an analysis of variance (ANOVA) to determine if there is a significant difference in the mean recovery times between the two medications.

# %%
import numpy as np
from scipy.stats import f_oneway

# Recovery times for Medication A and Medication B
medication_a = np.array([10, 12, 14, 11, 13])
medication_b = np.array([15, 17, 16, 14, 18])

# Perform one-way ANOVA
f_statistic, p_value = f_oneway(medication_a, medication_b)

# Print the ANOVA results
print("F-statistic:", f_statistic)
print("p-value:", p_value)

# Interpret the results
if p_value < 0.05:
    print("There is a significant difference in the mean recovery times between Medication A and Medication B.")
else:
    print("There is no significant difference in the mean recovery times between Medication A and Medication B.")
# Out:
# F-statistic: 16.0
# p-value: 0.003949772803445326
# There is a significant difference in the mean recovery times between Medication A and Medication B.

# %% [markdown]
# 10. Scenario: A company wants to analyze customer feedback ratings on a scale of 1 to 10. The data collected is
#
#  as follows:
#
#     [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#
#     Calculate the 75th percentile of the feedback ratings.
#
# Ans.
#
# Sorted list=[6, 7, 7, 8, 8, 8, 8, 9, 9, 10]
#
# N=10
#
# 75th percentile = (75/100)10=[7.5]=8, 8th number in sorted list is 9

# %% [markdown]
# 11. Scenario: A quality control department wants to test the weight consistency of a product. The weights of a sample of products are as follows:
#
#     [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#
#     Perform a hypothesis test to determine if the mean weight differs significantly from 10 grams.

# %%
from scipy.stats import ttest_1samp

weights = [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
population_mean = 10

t_statistic, p_value = ttest_1samp(weights, population_mean)

alpha = 0.05  # significance level

print("t-statistic:", t_statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject null hypothesis. The mean weight differs significantly from 10 grams.")
else:
    print("Fail to reject null hypothesis. The mean weight does not differ significantly from 10 grams.")
# Out:
# t-statistic: 1.5126584522688367
# p-value: 0.19077595151110102
# Fail to reject null hypothesis. The mean weight does not differ significantly from 10 grams.

# %% [markdown]
# 12. Scenario: A company wants to analyze the click-through rates of two different website designs. The number of clicks for each design is as follows:
#
#     Design A: [100, 120, 110, 90, 95]
#
#     Design B: [80, 85, 90, 95, 100]
#
#     Perform a chi-square test to determine if there is a significant difference in the click-through rates between the two designs.

# %%
from scipy.stats import chi2_contingency

design_a = [100, 120, 110, 90, 95]
design_b = [80, 85, 90, 95, 100]

observed = [design_a, design_b]

chi2, p_value, dof, expected = chi2_contingency(observed)

alpha = 0.05  # significance level

print("Chi-square statistic:", chi2)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject null hypothesis. There is a significant difference in click-through rates between the two designs.")
else:
    print("Fail to reject null hypothesis. There is no significant difference in click-through rates between the two designs.")
# Out:
# Chi-square statistic: 6.110658166925435
# p-value: 0.19103526314060293
# Fail to reject null hypothesis. There is no significant difference in click-through rates between the two designs.

# %% [markdown]
# 13. Scenario: A survey is conducted to measure customer satisfaction with a product on a scale of 1 to 10. The data collected is as follows:
#
#     [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#
#     Calculate the 95% confidence interval for the population mean satisfaction score.

# %%
import numpy as np
from scipy.stats import t

data = [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
confidence_level = 0.95

sample_mean = np.mean(data)
sample_std = np.std(data, ddof=1)  # ddof=1 for sample standard deviation
sample_size = len(data)

critical_value = t.ppf((1 + confidence_level) / 2, df=sample_size - 1)
standard_error = sample_std / np.sqrt(sample_size)

confidence_interval = sample_mean + critical_value * standard_error

lower_bound = sample_mean - critical_value * standard_error
upper_bound = sample_mean + critical_value * standard_error

print("95% Confidence Interval: [{:.2f}, {:.2f}]".format(lower_bound, upper_bound))
# Out:
# 95% Confidence Interval: [7.04, 8.76]

# %% [markdown]
# 14. Scenario: A company wants to analyze the effect of temperature on product performance. The data collected is as follows:
#
#     Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
#
#     Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
#     Perform a simple linear regression to predict performance based on temperature.

# %%
import numpy as np
from scipy import stats

temperature = np.array([20, 22, 23, 19, 21])
performance = np.array([8, 7, 9, 6, 8])

slope, intercept, r_value, p_value, std_err = stats.linregress(temperature, performance)

print("Slope:", slope)
print("Intercept:", intercept)
print("R-squared:", r_value**2)
print("p-value:", p_value)
print("Standard error:", std_err)
# Out:
# Slope: 0.5
# Intercept: -2.9000000000000004
# R-squared: 0.4807692307692307
# p-value: 0.19417134561205843
# Standard error: 0.30000000000000004

# %% [markdown]
# 15. Scenario: A study is conducted to compare the preferences of two groups of participants. The preferences are measured on a Likert scale from 1 to 5. The data collected is as follows:
#
#     Group A: [4, 3, 5, 2, 4]
#
#     Group B: [3, 2, 4, 3, 3]
#
#     Perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between the two groups.

# %%
from scipy.stats import mannwhitneyu

group_a = [4, 3, 5, 2, 4]
group_b = [3, 2, 4, 3, 3]

statistic, p_value = mannwhitneyu(group_a, group_b, alternative='two-sided')

alpha = 0.05  # significance level

print("Mann-Whitney U statistic:", statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject null hypothesis. There is a significant difference in median preferences between the two groups.")
else:
    print("Fail to reject null hypothesis. There is no significant difference in median preferences between the two groups.")
# Out:
# Mann-Whitney U statistic: 17.0
# p-value: 0.380836480306712
# Fail to reject null hypothesis. There is no significant difference in median preferences between the two groups.

# %% [markdown]
# 16. Scenario: A company wants to analyze the distribution of customer ages. The data collected is as follows:
#
#     [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
#     Calculate the interquartile range (IQR) of the ages.

# %%
import numpy as np

ages = [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]

Q1 = np.percentile(ages, 25)
Q3 = np.percentile(ages, 75)

IQR = Q3 - Q1

print("Interquartile Range (IQR):", IQR)
# Out:
# Interquartile Range (IQR): 22.5

# %% [markdown]
# 17. Scenario: A study is conducted to compare the performance of three different machine learning algorithms. The accuracy scores for each algorithm are as follows:
#
#     Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
#
#     Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
#
#     Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#
#     Perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the algorithms.

# %%
from scipy.stats import kruskal

algorithm_a = [0.85, 0.80, 0.82, 0.87, 0.83]
algorithm_b = [0.78, 0.82, 0.84, 0.80, 0.79]
algorithm_c = [0.90, 0.88, 0.89, 0.86, 0.87]

statistic, p_value = kruskal(algorithm_a, algorithm_b, algorithm_c)

alpha = 0.05  # significance level

print("Kruskal-Wallis statistic:", statistic)
print("p-value:", p_value)

if p_value < alpha:
    print("Reject null hypothesis. There is a significant difference in median accuracy scores between the algorithms.")
else:
    print("Fail to reject null hypothesis. There is no significant difference in median accuracy scores between the algorithm")
# Out:
# Kruskal-Wallis statistic: 9.696947935368053
# p-value: 0.007840333026249539
# Reject null hypothesis. There is a significant difference in median accuracy scores between the algorithms.

# %% [markdown]
# 18. Scenario: A company wants to analyze the effect of price on sales. The data collected is as follows:
#
#     Price (in dollars): [10, 15, 12, 8, 14]
#
#     Sales: [100, 80, 90, 110, 95]
#
#     Perform a simple linear regression to predict sales based on price.

# %%
import numpy as np
from scipy import stats

price = np.array([10, 15, 12, 8, 14])
sales = np.array([100, 80, 90, 110, 95])

slope, intercept, r_value, p_value, std_err = stats.linregress(price, sales)

print("Slope:", slope)
print("Intercept:", intercept)
print("R-squared:", r_value**2)
print("p-value:", p_value)
print("Standard error:", std_err)
# Out:
# Slope: -3.506097560975609
# Intercept: 136.3719512195122
# R-squared: 0.8064024390243901
# p-value: 0.03850178234753776
# Standard error: 0.9918303504036147

# %% [markdown]
# 19. Scenario: A survey is conducted to measure the satisfaction levels of customers with a new product. The data collected is as follows:
#
#     [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#
#     Calculate the standard error of the mean satisfaction score.

# %% [markdown]
# To calculate the standard error of the mean satisfaction score, you need to divide the standard deviation of the data by the square root of the sample size. Here are the steps:
#
# Calculate the mean of the satisfaction scores: Mean = (7 + 8 + 9 + 6 + 8 + 7 + 9 + 7 + 8 + 7) / 10 = 76 / 10 = 7.6
#
# Calculate the differences between each satisfaction score and the mean: Differences = [7 - 7.6, 8 - 7.6, 9 - 7.6, 6 - 7.6, 8 - 7.6, 7 - 7.6, 9 - 7.6, 7 - 7.6, 8 - 7.6, 7 - 7.6] = [-0.6, 0.4, 1.4, -1.6, 0.4, -0.6, 1.4, -0.6, 0.4, -0.6]
#
# Square each difference: Squared Differences = [(-0.6)^2, 0.4^2, 1.4^2, (-1.6)^2, 0.4^2, (-0.6)^2, 1.4^2, (-0.6)^2, 0.4^2, (-0.6)^2] = [0.36, 0.16, 1.96, 2.56, 0.16, 0.36, 1.96, 0.36, 0.16, 0.36]
#
# Calculate the variance by taking the average of the squared differences: Variance = (0.36 + 0.16 + 1.96 + 2.56 + 0.16 + 0.36 + 1.96 + 0.36 + 0.16 + 0.36) / 10 = 9.08 / 10 = 0.908
#
# Calculate the standard deviation by taking the square root of the variance: Standard Deviation = √0.908 ≈ 0.953
#
# Calculate the standard error of the mean by dividing the standard deviation by the square root of the sample size: Standard Error = 0.953 / √10 ≈ 0.301
#
# Therefore, the standard error of the mean satisfaction score is approximately 0.301.

# %% [markdown]
# 20. Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
#
#     Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
#
#     Sales (in thousands): [25, 30, 28, 20, 26]
#
#     Perform a multiple regression analysis to predict sales based on advertising expenditure.

# %%
import numpy as np
import statsmodels.api as sm

advertising_expenditure = np.array([10, 15, 12, 8, 14])
sales = np.array([25, 30, 28, 20, 26])

# Add a constant term to the predictor variable
X = sm.add_constant(advertising_expenditure)

# Create the OLS (Ordinary Least Squares) model
model = sm.OLS(sales, X)

# Fit the model to the data
results = model.fit()

# Print the summary of the regression analysis
print(results.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.767
# Model:                            OLS   Adj. R-squared:                  0.689
# Method:                 Least Squares   F-statistic:                     9.872
# Date:                Fri, 21 Jul 2023   Prob (F-statistic):             0.0516
# Time:                        21:37:48   Log-Likelihood:                -9.5288
# No. Observations:                   5   AIC:                             23.06
# Df Residuals:                       3   BIC:                             22.28
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         12.2012      4.429      2.755      0.070      -1.893      26.296
# ...
